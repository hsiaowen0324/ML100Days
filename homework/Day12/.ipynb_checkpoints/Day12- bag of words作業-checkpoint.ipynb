# %% [markdown]
# ## 作業目標：搭建一個bag of words模型

# %%
import pandas as pd
import nltk
#nltk.download()
import numpy as np
dataset=pd.read_csv('Restaurant_Reviews.tsv',delimiter='\t',quoting=3)
corpus=dataset['Review'].values

# %% [markdown]
# ### 從文本中取出所有單字

# %%
#使用 word_tokenize 可以進行斷詞
whole_words = []
for sentence in corpus:
    tokenized_sentence = nltk.tokenize.word_tokenize(sentence)
    for word in tokenized_sentence:
        whole_words.append(word)

# %% [markdown]
# ### 移除重複單字

# %%
#內建集合 set 資料結構對列表進行重複資料刪除。set 作為資料結構，在設計上保證內部元素都是唯一的。但元素的順序會改變
whole_words = set(whole_words)
print('共有{}個單字'.format(len(whole_words)))
# Out:
# 共有2351個單字

# %% [markdown]
# ### 建立字典使每一個單字有對應數值

# %%
word_index = {}
index_word = {}
n = 0
for word in whole_words:
    word_index.update({word:n})
    index_word.update({n:word})
    n +=1

# %%
word_index
# Out:
# {'best': 0,
#  'vomited': 1,
#  'each': 2,
#  'wow': 3,
#  'food': 4,
#  'oven': 5,
#  'Sadly': 6,
#  'boy': 7,
#  'bug': 8,
#  'across': 9,
#  'decide': 10,
#  'bacon': 11,
#  'tapas': 12,
#  'crowd': 13,
#  'outshining': 14,
#  'prime': 15,
#  'coziness': 16,
#  'away': 17,
#  'get': 18,
#  'honor': 19,
#  'restaurants': 20,
#  'Costco': 21,
#  'know': 22,
#  'undercooked': 23,
#  'eating': 24,
#  'waiter': 25,
#  'reasonably': 26,
#  'late': 27,
#  'employees': 28,
#  'T.': 29,
#  'amazing': 30,
#  'always': 31,
#  'court': 32,
#  'world': 33,
#  'tepid': 34,
#  '1.5lb': 35,
#  'STEP': 36,
#  'Eve': 37,
#  'neighborhood': 38,
#  'case': 39,
#  'cooked': 40,
#  'High-quality': 41,
#  'hello': 42,
#  'privileged': 43,
#  'surprised': 44,
#  'quantity': 45,
#  'Caesar': 46,
#  'over': 47,
#  'delicate': 48,
#  'Based': 49,
#  'Generous': 50,
#  'thinly': 51,
#  'mojitos': 52,
#  'satisfied': 53,
#  'favorite': 54,
#  'bread': 55,
#  'bought': 56,
#  'prices': 57,
#  'douchey': 58,
#  'managed': 59,
#  'daily': 60,
#  'incredibly': 61,
#  'Really': 62,
#  'donut': 63,
#  'cost': 64,
#  'liking': 65,
#  'Salads': 66,
#  'while': 67,
#  'soooooo': 68,
#  "'ve": 69,
#  'shoots': 70,
#  'large': 71,
#  'talking': 72,
#  'over-hip': 73,
#  'legit': 74,
#  'rib': 75,
#  'All': 76,
#  'corn': 77,
#  'front': 78,
#  'Nicest': 79,
#  'familiar': 80,
#  'mesquite': 81,
#  'Loved': 82,
#  'with': 83,
#  'unfortunately': 84,
#  'since': 85,
#  'cashew': 86,
#  'red': 87,
#  'They': 88,
#  'Large': 89,
#  'man': 90,
#  'Probably': 91,
#  'thirty': 92,
#  'mains': 93,
#  'delightful': 94,
#  'hungry': 95,
#  'Aria': 96,
#  'whether': 97,
#  'delicioso': 98,
#  'Fridays': 99,
#  'charcoal': 100,
#  'disbelief': 101,
#  'However': 102,
#  'monster': 103,
#  'wants': 104,
#  'beateous': 105,
#  'inch': 106,
#  'Albondigas': 107,
#  'services': 108,
#  'quickly': 109,
#  'Filet': 110,
#  'grilled': 111,
#  'Similarly': 112,
#  'until': 113,
#  'die': 114,
#  'Mmmm': 115,
#  'seating': 116,
#  'spices': 117,
#  'styrofoam': 118,
#  'delivery': 119,
#  'take': 120,
#  'Reasonably': 121,
#  'cooking': 122,
#  'WORST': 123,
#  'industry': 124,
#  'item': 125,
#  'letdown': 126,
#  'break': 127,
#  'songs': 128,
#  'location': 129,
#  'else': 130,
#  'Chinese': 131,
#  'fella': 132,
#  'famous': 133,
#  'sore': 134,
#  'at': 135,
#  'warmer': 136,
#  'fair': 137,
#  'rating': 138,
#  'STALE': 139,
#  'OK': 140,
#  'Crystals': 141,
#  'disappointed': 142,
#  'customize': 143,
#  'crust': 144,
#  'night': 145,
#  'rated': 146,
#  'recently': 147,
#  'dates': 148,
#  'fan': 149,
#  'wash': 150,
#  'overpriced': 151,
#  'tops': 152,
#  'MANY': 153,
#  'positive': 154,
#  'WILL': 155,
#  'vodka': 156,
#  'killer': 157,
#  'bloddy': 158,
#  'Come': 159,
#  'steak': 160,
#  'pizza': 161,
#  'green': 162,
#  'star': 163,
#  'offers': 164,
#  'cafe': 165,
#  'convenient': 166,
#  'editing': 167,
#  'expert/connisseur': 168,
#  'potatoes': 169,
#  'frustrated': 170,
#  'auju': 171,
#  'having': 172,
#  'Otto': 173,
#  'mixed': 174,
#  'combos': 175,
#  'prepare': 176,
#  'mein': 177,
#  'reviewer': 178,
#  'genuinely': 179,
#  'Pros': 180,
#  'At': 181,
#  'tastings': 182,
#  'gyro': 183,
#  'coconut': 184,
#  'website': 185,
#  'drive': 186,
#  'placed': 187,
#  'likes': 188,
#  'my': 189,
#  'takeout': 190,
#  'either': 191,
#  'petrified': 192,
#  'someone': 193,
#  'Only': 194,
#  'biggest': 195,
#  'Third': 196,
#  'brisket': 197,
#  'modern': 198,
#  'LEGIT': 199,
#  'Pineapple': 200,
#  'Host': 201,
#  'postinos': 202,
#  'fresh': 203,
#  'car': 204,
#  'particular': 205,
#  'flavorless': 206,
#  'sugary': 207,
#  'hits': 208,
#  'indicate': 209,
#  'drenched': 210,
#  'strings': 211,
#  'efficient': 212,
#  'Indian': 213,
#  'fantastic': 214,
#  'gluten': 215,
#  'Perhaps': 216,
#  'Bouchon': 217,
#  'Now': 218,
#  'going': 219,
#  'servers': 220,
#  'charge': 221,
#  'Wife': 222,
#  'Do': 223,
#  'outside': 224,
#  'exceptional': 225,
#  'imaginative': 226,
#  'pneumatic': 227,
#  'anything': 228,
#  'cranberry': 229,
#  'salmon': 230,
#  'thats': 231,
#  'app': 232,
#  'shrimp': 233,
#  'other': 234,
#  'continue': 235,
#  'Paradise': 236,
#  'apologize': 237,
#  'thick': 238,
#  'guest': 239,
#  'three': 240,
#  'dishes': 241,
#  'pepper': 242,
#  'combination': 243,
#  'vacant': 244,
#  'struggle': 245,
#  'drag': 246,
#  'Toast': 247,
#  'Left': 248,
#  'rice': 249,
#  'Both': 250,
#  'serivce': 251,
#  'Gordon': 252,
#  'yucky': 253,
#  'pears': 254,
#  'As': 255,
#  'terrible': 256,
#  'grow': 257,
#  'something': 258,
#  '..': 259,
#  'WEAK': 260,
#  'moist': 261,
#  'Gringos': 262,
#  'passed': 263,
#  'containers': 264,
#  'side': 265,
#  'complain': 266,
#  'check': 267,
#  'teamwork': 268,
#  'Pita': 269,
#  'Unfortunately': 270,
#  'ourselves': 271,
#  'petty': 272,
#  'cavier': 273,
#  'OVERPRICED': 274,
#  'bring': 275,
#  'into': 276,
#  'Han': 277,
#  'tailored': 278,
#  'She': 279,
#  'tragedy': 280,
#  'fries': 281,
#  'rave': 282,
#  'driving': 283,
#  'date': 284,
#  'rather': 285,
#  'Google': 286,
#  'prompt': 287,
#  'mistake': 288,
#  'mussels': 289,
#  'Bland': 290,
#  'Wo': 291,
#  'Check': 292,
#  'sucker': 293,
#  'enthusiastic': 294,
#  'Mirage': 295,
#  'Jeff': 296,
#  'wanted': 297,
#  'regularly': 298,
#  'because': 299,
#  'PEOPLE': 300,
#  'dish': 301,
#  'hereas': 302,
#  'seafood': 303,
#  'less': 304,
#  'An': 305,
#  'sucked': 306,
#  '30': 307,
#  'dipping': 308,
#  'Bad': 309,
#  'Rick': 310,
#  'Up': 311,
#  'Roll': 312,
#  'holiday': 313,
#  'together': 314,
#  'pace': 315,
#  "'re": 316,
#  'Before': 317,
#  'pale': 318,
#  'Panna': 319,
#  'breakfast': 320,
#  'simple': 321,
#  'patty': 322,
#  'NYC': 323,
#  'gold': 324,
#  'generous': 325,
#  'mention': 326,
#  'salt': 327,
#  'scallop': 328,
#  'Took': 329,
#  'Casino': 330,
#  'mostly': 331,
#  'reviewing': 332,
#  'Café': 333,
#  'first': 334,
#  'tolerance': 335,
#  'professional': 336,
#  'very': 337,
#  'judge': 338,
#  'slow': 339,
#  'Scottsdale': 340,
#  'temp.I': 341,
#  'flirting': 342,
#  'Bachi': 343,
#  'cakes': 344,
#  'lightly': 345,
#  'another': 346,
#  'luck': 347,
#  'poured': 348,
#  'shower': 349,
#  'quality': 350,
#  'cart': 351,
#  'Why': 352,
#  'wine': 353,
#  'condiment': 354,
#  'Smashburger': 355,
#  'mind': 356,
#  'felt': 357,
#  'uploaded': 358,
#  'eggplant': 359,
#  'colder': 360,
#  '...': 361,
#  'me': 362,
#  'told': 363,
#  'Bay': 364,
#  'picture': 365,
#  'love': 366,
#  'spinach': 367,
#  'different': 368,
#  'imagined': 369,
#  'heat': 370,
#  'blows': 371,
#  'say': 372,
#  'raspberry': 373,
#  'Eew': 374,
#  'multi-grain': 375,
#  'smoothies': 376,
#  'hankering': 377,
#  'Plus': 378,
#  'ignore': 379,
#  'Awesome': 380,
#  'crab': 381,
#  'downtown': 382,
#  'buying': 383,
#  'thanks': 384,
#  'head': 385,
#  'tell': 386,
#  'peanuts': 387,
#  'mayo': 388,
#  'enjoyed': 389,
#  'ladies': 390,
#  'naan': 391,
#  'both': 392,
#  'sub': 393,
#  'AND': 394,
#  'bar': 395,
#  'soup': 396,
#  'leave': 397,
#  'making': 398,
#  'Khao': 399,
#  'think': 400,
#  'velvet': 401,
#  'disrespected': 402,
#  'options': 403,
#  'honestly': 404,
#  'girlfriend': 405,
#  'setting': 406,
#  'recommendation': 407,
#  'disgrace': 408,
#  'Best': 409,
#  'club': 410,
#  'carbs': 411,
#  'smells': 412,
#  'Strike': 413,
#  'Disappointing': 414,
#  'see': 415,
#  'Mediterranean': 416,
#  'definately': 417,
#  'capers': 418,
#  'rotating': 419,
#  'loving': 420,
#  'ranch': 421,
#  'bye': 422,
#  'Bisque': 423,
#  'lil': 424,
#  'mid': 425,
#  'look': 426,
#  'Damn': 427,
#  'fabulous': 428,
#  'food/service': 429,
#  'hurry': 430,
#  'Terrible': 431,
#  'Crust': 432,
#  'NOT': 433,
#  'also': 434,
#  'sense': 435,
#  'These': 436,
#  'dinners': 437,
#  'read': 438,
#  'describing': 439,
#  'presentation': 440,
#  'immediately': 441,
#  'tea': 442,
#  'metro': 443,
#  'Bunch': 444,
#  'you': 445,
#  'Halibut': 446,
#  'wonderful': 447,
#  'mary': 448,
#  'BARE': 449,
#  'Hawaiian': 450,
#  'strangers': 451,
#  'actual': 452,
#  'signs': 453,
#  'limited': 454,
#  'decor': 455,
#  'received': 456,
#  'awful': 457,
#  'salads': 458,
#  'quaint': 459,
#  'flop': 460,
#  'dime': 461,
#  '--': 462,
#  'served': 463,
#  'Crema': 464,
#  'spaghetti': 465,
#  'list': 466,
#  'glass': 467,
#  'consider': 468,
#  'OMG': 469,
#  'probably': 470,
#  'SHOULD': 471,
#  'slices': 472,
#  'reheated': 473,
#  'Sprouts': 474,
#  'freaking': 475,
#  'calligraphy': 476,
#  'fear': 477,
#  'discount': 478,
#  'strawberry': 479,
#  'ten': 480,
#  'complete': 481,
#  'Waiter': 482,
#  'lady': 483,
#  'took': 484,
#  'grease': 485,
#  'powdered': 486,
#  'Mellow': 487,
#  'melted': 488,
#  'lawyers': 489,
#  'today': 490,
#  'rarely': 491,
#  'fact': 492,
#  'Although': 493,
#  'son': 494,
#  'sauce': 495,
#  'party': 496,
#  'tiny': 497,
#  'beautiful': 498,
#  'self': 499,
#  'completely': 500,
#  'recommending': 501,
#  'wasting': 502,
#  'opinion': 503,
#  'yet': 504,
#  'round': 505,
#  'looked': 506,
#  'trip': 507,
#  'peas': 508,
#  'EXPERIENCE': 509,
#  'dropped': 510,
#  'he': 511,
#  'Bacon': 512,
#  'white': 513,
#  'steakhouse': 514,
#  'watered': 515,
#  'recommended': 516,
#  'mediocre': 517,
#  'during': 518,
#  'Waitress': 519,
#  'TOTAL': 520,
#  'Bean': 521,
#  'exceeding': 522,
#  'understand': 523,
#  'spots': 524,
#  'last': 525,
#  'caterpillar': 526,
#  'area': 527,
#  'relocated': 528,
#  'promptly': 529,
#  'connoisseur': 530,
#  'garden': 531,
#  'waitresses': 532,
#  'receives': 533,
#  'par': 534,
#  'dreamed': 535,
#  'restaraunt': 536,
#  'requested': 537,
#  'missing': 538,
#  'fav': 539,
#  'ordering': 540,
#  'word': 541,
#  'that': 542,
#  'charged': 543,
#  'Classy/warm': 544,
#  'disgusting': 545,
#  'real': 546,
#  'quit': 547,
#  'Special': 548,
#  'unless': 549,
#  'pop': 550,
#  'ache': 551,
#  'transcendant': 552,
#  'disgraceful': 553,
#  'Gyros': 554,
#  'mortified': 555,
#  'fell': 556,
#  'onion': 557,
#  'relaxed': 558,
#  'name': 559,
#  'thought': 560,
#  'oh': 561,
#  'non-fancy': 562,
#  'ripped': 563,
#  'awkward': 564,
#  'brick': 565,
#  'Main': 566,
#  'this': 567,
#  'reservation': 568,
#  'Hiro': 569,
#  'Greek': 570,
#  'TIME': 571,
#  'changing': 572,
#  'groups': 573,
#  '2': 574,
#  'untoasted': 575,
#  'Mary': 576,
#  'relationship': 577,
#  'nutshell': 578,
#  'outdoor': 579,
#  'why': 580,
#  'mom': 581,
#  'nicest': 582,
#  'Pricing': 583,
#  'glad': 584,
#  'Taco': 585,
#  'working/eating': 586,
#  'After': 587,
#  'lots': 588,
#  'poisoning': 589,
#  'Thoroughly': 590,
#  'negligent': 591,
#  'Long': 592,
#  'wife': 593,
#  'smelled': 594,
#  'Mom': 595,
#  'tried': 596,
#  'ice': 597,
#  'FS': 598,
#  'ago': 599,
#  'writing': 600,
#  'sides': 601,
#  'made': 602,
#  'money': 603,
#  'veal': 604,
#  'covered': 605,
#  'deep': 606,
#  'begin': 607,
#  'Gave': 608,
#  ')': 609,
#  'stinks': 610,
#  'cool': 611,
#  'sad': 612,
#  'Maria': 613,
#  'lunch': 614,
#  'Baseball': 615,
#  'worst/annoying': 616,
#  'pumpkin': 617,
#  'under': 618,
#  'saving': 619,
#  'Dylan': 620,
#  'Delicious': 621,
#  'wo': 622,
#  'entire': 623,
#  'register': 624,
#  'hot': 625,
#  'pucks': 626,
#  'will': 627,
#  'haunt': 628,
#  'cheese': 629,
#  'bigger': 630,
#  'venture': 631,
#  'accordingly': 632,
#  'subpar': 633,
#  'burgers': 634,
#  'blue': 635,
#  'suffers': 636,
#  'UNREAL': 637,
#  'allergy': 638,
#  'shawarrrrrrma': 639,
#  'brownish': 640,
#  'customer': 641,
#  'goat': 642,
#  'fat': 643,
#  'Christmas': 644,
#  'recall': 645,
#  'suggestions': 646,
#  'hooked': 647,
#  'absolute': 648,
#  'Waited': 649,
#  'dressing': 650,
#  'tongue': 651,
#  'disappoint': 652,
#  'bites': 653,
#  'Always': 654,
#  'milkshake': 655,
#  'myself': 656,
#  'low': 657,
#  'giant': 658,
#  'Soggy': 659,
#  'article': 660,
#  'extensive': 661,
#  'Veggitarian': 662,
#  'barely': 663,
#  'proclaimed': 664,
#  'gotten': 665,
#  'I': 666,
#  'poorly': 667,
#  'hilarious': 668,
#  'REAL': 669,
#  'etc': 670,
#  'dealing': 671,
#  'terrific': 672,
#  'But': 673,
#  'back': 674,
#  'turkey': 675,
#  'fry': 676,
#  'correction': 677,
#  'dry': 678,
#  'gone': 679,
#  'including': 680,
#  'Yelpers': 681,
#  'owner/chef': 682,
#  'pan': 683,
#  'to': 684,
#  'desserts': 685,
#  'bamboo': 686,
#  'bathrooms': 687,
#  'Carly': 688,
#  'flavor': 689,
#  'The': 690,
#  'ingredients': 691,
#  'DELICIOUS': 692,
#  'manager': 693,
#  'us': 694,
#  'appalling': 695,
#  'well': 696,
#  '30s': 697,
#  'anticipated': 698,
#  'Thus': 699,
#  'people': 700,
#  'hoping': 701,
#  'she': 702,
#  'putting': 703,
#  '4': 704,
#  'figured': 705,
#  'biscuits': 706,
#  'wrap': 707,
#  'live': 708,
#  'homemade': 709,
#  'trying': 710,
#  'cold': 711,
#  '&': 712,
#  'bowl': 713,
#  'gratuity': 714,
#  'shirt': 715,
#  'book': 716,
#  'Crostini': 717,
#  'college': 718,
#  'lot': 719,
#  'flavors': 720,
#  'considering': 721,
#  'grocery': 722,
#  'drink': 723,
#  'dog': 724,
#  'happened': 725,
#  'times': 726,
#  'moz': 727,
#  'stay': 728,
#  'smeared': 729,
#  'low-key': 730,
#  'treat': 731,
#  'Give': 732,
#  'apart': 733,
#  'dusted': 734,
#  'falafels': 735,
#  'living': 736,
#  'forever': 737,
#  'overwhelmed': 738,
#  'but': 739,
#  'steaks': 740,
#  'totally': 741,
#  'fluffy': 742,
#  'Breeze': 743,
#  'baby': 744,
#  'sit-down': 745,
#  'huge': 746,
#  'all': 747,
#  'officially': 748,
#  'chip': 749,
#  'Back': 750,
#  'mushrooms': 751,
#  'smaller': 752,
#  'tomato': 753,
#  'order': 754,
#  'wish': 755,
#  'assure': 756,
#  'reviews': 757,
#  'ways': 758,
#  'afternoon': 759,
#  'dedicated': 760,
#  'attached': 761,
#  'pita': 762,
#  'worries': 763,
#  '!': 764,
#  'of': 765,
#  'cannoli': 766,
#  'older': 767,
#  'Cartel': 768,
#  'or': 769,
#  'looks': 770,
#  'portions': 771,
#  'Cute': 772,
#  'hummus': 773,
#  'Everything': 774,
#  'bathroom': 775,
#  '40': 776,
#  'be': 777,
#  'similar': 778,
#  'added': 779,
#  'Kind': 780,
#  'Try': 781,
#  'sushi': 782,
#  'boba': 783,
#  'Any': 784,
#  'same': 785,
#  'Luke': 786,
#  'selection': 787,
#  'heads': 788,
#  'literally': 789,
#  'got': 790,
#  'dinner': 791,
#  'taco': 792,
#  'Rock': 793,
#  'noodles': 794,
#  'lukewarm': 795,
#  'speedy': 796,
#  'i': 797,
#  'bite': 798,
#  'fairly': 799,
#  'disagree': 800,
#  '7.85': 801,
#  'LOVED': 802,
#  'weekly': 803,
#  'spice': 804,
#  'coming': 805,
#  'Italian': 806,
#  'meat': 807,
#  'leaves': 808,
#  'close': 809,
#  'pulled': 810,
#  'touched': 811,
#  'above': 812,
#  'brings': 813,
#  'butter': 814,
#  'drastically': 815,
#  'excellent': 816,
#  'puree': 817,
#  'Ironman': 818,
#  'flair': 819,
#  'hamburger': 820,
#  'in-house': 821,
#  'fuzzy': 822,
#  'dirt': 823,
#  'closed': 824,
#  'play': 825,
#  'friends': 826,
#  'cover': 827,
#  'pissd': 828,
#  'expensive': 829,
#  'Spend': 830,
#  'NASTY': 831,
#  'Weird': 832,
#  'non-customer': 833,
#  'great': 834,
#  'crowds': 835,
#  'ravoli': 836,
#  'overhaul': 837,
#  'operation': 838,
#  'dough': 839,
#  'means': 840,
#  'Nothing': 841,
#  'M': 842,
#  'gave': 843,
#  'Also': 844,
#  'guests': 845,
#  'reduction': 846,
#  'boiled': 847,
#  'curry': 848,
#  'summarize': 849,
#  'violinists': 850,
#  'Boy': 851,
#  'Pho': 852,
#  'wrapped': 853,
#  'atmosphere': 854,
#  'rapidly': 855,
#  'If': 856,
#  'towards': 857,
#  'Seat': 858,
#  'Del': 859,
#  'Paying': 860,
#  'cause': 861,
#  'sauces': 862,
#  'him': 863,
#  'Japanese': 864,
#  'biscuit': 865,
#  'indoor': 866,
#  'downright': 867,
#  'whatsoever': 868,
#  'supposed': 869,
#  'Sunday': 870,
#  'mean': 871,
#  'tasteless': 872,
#  'silently': 873,
#  'deal': 874,
#  'garlic': 875,
#  'Burger': 876,
#  'employee': 877,
#  'vain': 878,
#  'reasonable': 879,
#  'Caballero': 880,
#  'them': 881,
#  'highlighted': 882,
#  'Service': 883,
#  'pho': 884,
#  'come': 885,
#  'Attack': 886,
#  'block': 887,
#  'succulent': 888,
#  'crawfish': 889,
#  'space': 890,
#  'forth': 891,
#  'pub': 892,
#  'brunch': 893,
#  'must': 894,
#  'market': 895,
#  'yay': 896,
#  'Thai': 897,
#  'Oh': 898,
#  'Nargile': 899,
#  'stepped': 900,
#  'human': 901,
#  'where': 902,
#  'legs': 903,
#  'baklava': 904,
#  'pine': 905,
#  'boring': 906,
#  'Favorite': 907,
#  'make': 908,
#  'short': 909,
#  'prepared': 910,
#  'fiancé': 911,
#  'Grill': 912,
#  'tough': 913,
#  'next': 914,
#  'so': 915,
#  'prefer': 916,
#  'small': 917,
#  'potato': 918,
#  'attention': 919,
#  'ended': 920,
#  'town': 921,
#  'yukon': 922,
#  'its': 923,
#  'seasoning': 924,
#  'maintaining': 925,
#  'deserves': 926,
#  'To': 927,
#  'smoke': 928,
#  'drunk': 929,
#  'No': 930,
#  'ate': 931,
#  'nigiri': 932,
#  'fine': 933,
#  'zero': 934,
#  'although': 935,
#  'Steak': 936,
#  'finger': 937,
#  'ball': 938,
#  'salty': 939,
#  'tender': 940,
#  'GREAT': 941,
#  'attack': 942,
#  'sorely': 943,
#  'ca': 944,
#  'boxes': 945,
#  'kitchen': 946,
#  'crazy': 947,
#  'year': 948,
#  'Mushroom': 949,
#  'Jamaican': 950,
#  'bill': 951,
#  'TOLD': 952,
#  'preparing': 953,
#  'joy': 954,
#  'Hopefully': 955,
#  'shops': 956,
#  'Same': 957,
#  'Coming': 958,
#  'wildly': 959,
#  'personally': 960,
#  'job': 961,
#  'correct': 962,
#  'pricey': 963,
#  'further': 964,
#  'class': 965,
#  'mouth': 966,
#  'Sushi': 967,
#  'So': 968,
#  'kind': 969,
#  'toasted': 970,
#  'loyal': 971,
#  'sliced': 972,
#  '$': 973,
#  'known': 974,
#  '%': 975,
#  'wall': 976,
#  'meet': 977,
#  '?': 978,
#  'dude': 979,
#  'ever': 980,
#  'chefs': 981,
#  'perpared': 982,
#  'trap': 983,
#  'want': 984,
#  'inflate': 985,
#  'That': 986,
#  'daughter': 987,
#  'exactly': 988,
#  'duck': 989,
#  'long': 990,
#  'Soups': 991,
#  'eel': 992,
#  'slaw': 993,
#  'avoided': 994,
#  'Much': 995,
#  'Talk': 996,
#  'ventilation': 997,
#  'Bussell': 998,
#  'packed': 999,
#  ...}

# %%
index_word
# Out:
# {0: 'best',
#  1: 'vomited',
#  2: 'each',
#  3: 'wow',
#  4: 'food',
#  5: 'oven',
#  6: 'Sadly',
#  7: 'boy',
#  8: 'bug',
#  9: 'across',
#  10: 'decide',
#  11: 'bacon',
#  12: 'tapas',
#  13: 'crowd',
#  14: 'outshining',
#  15: 'prime',
#  16: 'coziness',
#  17: 'away',
#  18: 'get',
#  19: 'honor',
#  20: 'restaurants',
#  21: 'Costco',
#  22: 'know',
#  23: 'undercooked',
#  24: 'eating',
#  25: 'waiter',
#  26: 'reasonably',
#  27: 'late',
#  28: 'employees',
#  29: 'T.',
#  30: 'amazing',
#  31: 'always',
#  32: 'court',
#  33: 'world',
#  34: 'tepid',
#  35: '1.5lb',
#  36: 'STEP',
#  37: 'Eve',
#  38: 'neighborhood',
#  39: 'case',
#  40: 'cooked',
#  41: 'High-quality',
#  42: 'hello',
#  43: 'privileged',
#  44: 'surprised',
#  45: 'quantity',
#  46: 'Caesar',
#  47: 'over',
#  48: 'delicate',
#  49: 'Based',
#  50: 'Generous',
#  51: 'thinly',
#  52: 'mojitos',
#  53: 'satisfied',
#  54: 'favorite',
#  55: 'bread',
#  56: 'bought',
#  57: 'prices',
#  58: 'douchey',
#  59: 'managed',
#  60: 'daily',
#  61: 'incredibly',
#  62: 'Really',
#  63: 'donut',
#  64: 'cost',
#  65: 'liking',
#  66: 'Salads',
#  67: 'while',
#  68: 'soooooo',
#  69: "'ve",
#  70: 'shoots',
#  71: 'large',
#  72: 'talking',
#  73: 'over-hip',
#  74: 'legit',
#  75: 'rib',
#  76: 'All',
#  77: 'corn',
#  78: 'front',
#  79: 'Nicest',
#  80: 'familiar',
#  81: 'mesquite',
#  82: 'Loved',
#  83: 'with',
#  84: 'unfortunately',
#  85: 'since',
#  86: 'cashew',
#  87: 'red',
#  88: 'They',
#  89: 'Large',
#  90: 'man',
#  91: 'Probably',
#  92: 'thirty',
#  93: 'mains',
#  94: 'delightful',
#  95: 'hungry',
#  96: 'Aria',
#  97: 'whether',
#  98: 'delicioso',
#  99: 'Fridays',
#  100: 'charcoal',
#  101: 'disbelief',
#  102: 'However',
#  103: 'monster',
#  104: 'wants',
#  105: 'beateous',
#  106: 'inch',
#  107: 'Albondigas',
#  108: 'services',
#  109: 'quickly',
#  110: 'Filet',
#  111: 'grilled',
#  112: 'Similarly',
#  113: 'until',
#  114: 'die',
#  115: 'Mmmm',
#  116: 'seating',
#  117: 'spices',
#  118: 'styrofoam',
#  119: 'delivery',
#  120: 'take',
#  121: 'Reasonably',
#  122: 'cooking',
#  123: 'WORST',
#  124: 'industry',
#  125: 'item',
#  126: 'letdown',
#  127: 'break',
#  128: 'songs',
#  129: 'location',
#  130: 'else',
#  131: 'Chinese',
#  132: 'fella',
#  133: 'famous',
#  134: 'sore',
#  135: 'at',
#  136: 'warmer',
#  137: 'fair',
#  138: 'rating',
#  139: 'STALE',
#  140: 'OK',
#  141: 'Crystals',
#  142: 'disappointed',
#  143: 'customize',
#  144: 'crust',
#  145: 'night',
#  146: 'rated',
#  147: 'recently',
#  148: 'dates',
#  149: 'fan',
#  150: 'wash',
#  151: 'overpriced',
#  152: 'tops',
#  153: 'MANY',
#  154: 'positive',
#  155: 'WILL',
#  156: 'vodka',
#  157: 'killer',
#  158: 'bloddy',
#  159: 'Come',
#  160: 'steak',
#  161: 'pizza',
#  162: 'green',
#  163: 'star',
#  164: 'offers',
#  165: 'cafe',
#  166: 'convenient',
#  167: 'editing',
#  168: 'expert/connisseur',
#  169: 'potatoes',
#  170: 'frustrated',
#  171: 'auju',
#  172: 'having',
#  173: 'Otto',
#  174: 'mixed',
#  175: 'combos',
#  176: 'prepare',
#  177: 'mein',
#  178: 'reviewer',
#  179: 'genuinely',
#  180: 'Pros',
#  181: 'At',
#  182: 'tastings',
#  183: 'gyro',
#  184: 'coconut',
#  185: 'website',
#  186: 'drive',
#  187: 'placed',
#  188: 'likes',
#  189: 'my',
#  190: 'takeout',
#  191: 'either',
#  192: 'petrified',
#  193: 'someone',
#  194: 'Only',
#  195: 'biggest',
#  196: 'Third',
#  197: 'brisket',
#  198: 'modern',
#  199: 'LEGIT',
#  200: 'Pineapple',
#  201: 'Host',
#  202: 'postinos',
#  203: 'fresh',
#  204: 'car',
#  205: 'particular',
#  206: 'flavorless',
#  207: 'sugary',
#  208: 'hits',
#  209: 'indicate',
#  210: 'drenched',
#  211: 'strings',
#  212: 'efficient',
#  213: 'Indian',
#  214: 'fantastic',
#  215: 'gluten',
#  216: 'Perhaps',
#  217: 'Bouchon',
#  218: 'Now',
#  219: 'going',
#  220: 'servers',
#  221: 'charge',
#  222: 'Wife',
#  223: 'Do',
#  224: 'outside',
#  225: 'exceptional',
#  226: 'imaginative',
#  227: 'pneumatic',
#  228: 'anything',
#  229: 'cranberry',
#  230: 'salmon',
#  231: 'thats',
#  232: 'app',
#  233: 'shrimp',
#  234: 'other',
#  235: 'continue',
#  236: 'Paradise',
#  237: 'apologize',
#  238: 'thick',
#  239: 'guest',
#  240: 'three',
#  241: 'dishes',
#  242: 'pepper',
#  243: 'combination',
#  244: 'vacant',
#  245: 'struggle',
#  246: 'drag',
#  247: 'Toast',
#  248: 'Left',
#  249: 'rice',
#  250: 'Both',
#  251: 'serivce',
#  252: 'Gordon',
#  253: 'yucky',
#  254: 'pears',
#  255: 'As',
#  256: 'terrible',
#  257: 'grow',
#  258: 'something',
#  259: '..',
#  260: 'WEAK',
#  261: 'moist',
#  262: 'Gringos',
#  263: 'passed',
#  264: 'containers',
#  265: 'side',
#  266: 'complain',
#  267: 'check',
#  268: 'teamwork',
#  269: 'Pita',
#  270: 'Unfortunately',
#  271: 'ourselves',
#  272: 'petty',
#  273: 'cavier',
#  274: 'OVERPRICED',
#  275: 'bring',
#  276: 'into',
#  277: 'Han',
#  278: 'tailored',
#  279: 'She',
#  280: 'tragedy',
#  281: 'fries',
#  282: 'rave',
#  283: 'driving',
#  284: 'date',
#  285: 'rather',
#  286: 'Google',
#  287: 'prompt',
#  288: 'mistake',
#  289: 'mussels',
#  290: 'Bland',
#  291: 'Wo',
#  292: 'Check',
#  293: 'sucker',
#  294: 'enthusiastic',
#  295: 'Mirage',
#  296: 'Jeff',
#  297: 'wanted',
#  298: 'regularly',
#  299: 'because',
#  300: 'PEOPLE',
#  301: 'dish',
#  302: 'hereas',
#  303: 'seafood',
#  304: 'less',
#  305: 'An',
#  306: 'sucked',
#  307: '30',
#  308: 'dipping',
#  309: 'Bad',
#  310: 'Rick',
#  311: 'Up',
#  312: 'Roll',
#  313: 'holiday',
#  314: 'together',
#  315: 'pace',
#  316: "'re",
#  317: 'Before',
#  318: 'pale',
#  319: 'Panna',
#  320: 'breakfast',
#  321: 'simple',
#  322: 'patty',
#  323: 'NYC',
#  324: 'gold',
#  325: 'generous',
#  326: 'mention',
#  327: 'salt',
#  328: 'scallop',
#  329: 'Took',
#  330: 'Casino',
#  331: 'mostly',
#  332: 'reviewing',
#  333: 'Café',
#  334: 'first',
#  335: 'tolerance',
#  336: 'professional',
#  337: 'very',
#  338: 'judge',
#  339: 'slow',
#  340: 'Scottsdale',
#  341: 'temp.I',
#  342: 'flirting',
#  343: 'Bachi',
#  344: 'cakes',
#  345: 'lightly',
#  346: 'another',
#  347: 'luck',
#  348: 'poured',
#  349: 'shower',
#  350: 'quality',
#  351: 'cart',
#  352: 'Why',
#  353: 'wine',
#  354: 'condiment',
#  355: 'Smashburger',
#  356: 'mind',
#  357: 'felt',
#  358: 'uploaded',
#  359: 'eggplant',
#  360: 'colder',
#  361: '...',
#  362: 'me',
#  363: 'told',
#  364: 'Bay',
#  365: 'picture',
#  366: 'love',
#  367: 'spinach',
#  368: 'different',
#  369: 'imagined',
#  370: 'heat',
#  371: 'blows',
#  372: 'say',
#  373: 'raspberry',
#  374: 'Eew',
#  375: 'multi-grain',
#  376: 'smoothies',
#  377: 'hankering',
#  378: 'Plus',
#  379: 'ignore',
#  380: 'Awesome',
#  381: 'crab',
#  382: 'downtown',
#  383: 'buying',
#  384: 'thanks',
#  385: 'head',
#  386: 'tell',
#  387: 'peanuts',
#  388: 'mayo',
#  389: 'enjoyed',
#  390: 'ladies',
#  391: 'naan',
#  392: 'both',
#  393: 'sub',
#  394: 'AND',
#  395: 'bar',
#  396: 'soup',
#  397: 'leave',
#  398: 'making',
#  399: 'Khao',
#  400: 'think',
#  401: 'velvet',
#  402: 'disrespected',
#  403: 'options',
#  404: 'honestly',
#  405: 'girlfriend',
#  406: 'setting',
#  407: 'recommendation',
#  408: 'disgrace',
#  409: 'Best',
#  410: 'club',
#  411: 'carbs',
#  412: 'smells',
#  413: 'Strike',
#  414: 'Disappointing',
#  415: 'see',
#  416: 'Mediterranean',
#  417: 'definately',
#  418: 'capers',
#  419: 'rotating',
#  420: 'loving',
#  421: 'ranch',
#  422: 'bye',
#  423: 'Bisque',
#  424: 'lil',
#  425: 'mid',
#  426: 'look',
#  427: 'Damn',
#  428: 'fabulous',
#  429: 'food/service',
#  430: 'hurry',
#  431: 'Terrible',
#  432: 'Crust',
#  433: 'NOT',
#  434: 'also',
#  435: 'sense',
#  436: 'These',
#  437: 'dinners',
#  438: 'read',
#  439: 'describing',
#  440: 'presentation',
#  441: 'immediately',
#  442: 'tea',
#  443: 'metro',
#  444: 'Bunch',
#  445: 'you',
#  446: 'Halibut',
#  447: 'wonderful',
#  448: 'mary',
#  449: 'BARE',
#  450: 'Hawaiian',
#  451: 'strangers',
#  452: 'actual',
#  453: 'signs',
#  454: 'limited',
#  455: 'decor',
#  456: 'received',
#  457: 'awful',
#  458: 'salads',
#  459: 'quaint',
#  460: 'flop',
#  461: 'dime',
#  462: '--',
#  463: 'served',
#  464: 'Crema',
#  465: 'spaghetti',
#  466: 'list',
#  467: 'glass',
#  468: 'consider',
#  469: 'OMG',
#  470: 'probably',
#  471: 'SHOULD',
#  472: 'slices',
#  473: 'reheated',
#  474: 'Sprouts',
#  475: 'freaking',
#  476: 'calligraphy',
#  477: 'fear',
#  478: 'discount',
#  479: 'strawberry',
#  480: 'ten',
#  481: 'complete',
#  482: 'Waiter',
#  483: 'lady',
#  484: 'took',
#  485: 'grease',
#  486: 'powdered',
#  487: 'Mellow',
#  488: 'melted',
#  489: 'lawyers',
#  490: 'today',
#  491: 'rarely',
#  492: 'fact',
#  493: 'Although',
#  494: 'son',
#  495: 'sauce',
#  496: 'party',
#  497: 'tiny',
#  498: 'beautiful',
#  499: 'self',
#  500: 'completely',
#  501: 'recommending',
#  502: 'wasting',
#  503: 'opinion',
#  504: 'yet',
#  505: 'round',
#  506: 'looked',
#  507: 'trip',
#  508: 'peas',
#  509: 'EXPERIENCE',
#  510: 'dropped',
#  511: 'he',
#  512: 'Bacon',
#  513: 'white',
#  514: 'steakhouse',
#  515: 'watered',
#  516: 'recommended',
#  517: 'mediocre',
#  518: 'during',
#  519: 'Waitress',
#  520: 'TOTAL',
#  521: 'Bean',
#  522: 'exceeding',
#  523: 'understand',
#  524: 'spots',
#  525: 'last',
#  526: 'caterpillar',
#  527: 'area',
#  528: 'relocated',
#  529: 'promptly',
#  530: 'connoisseur',
#  531: 'garden',
#  532: 'waitresses',
#  533: 'receives',
#  534: 'par',
#  535: 'dreamed',
#  536: 'restaraunt',
#  537: 'requested',
#  538: 'missing',
#  539: 'fav',
#  540: 'ordering',
#  541: 'word',
#  542: 'that',
#  543: 'charged',
#  544: 'Classy/warm',
#  545: 'disgusting',
#  546: 'real',
#  547: 'quit',
#  548: 'Special',
#  549: 'unless',
#  550: 'pop',
#  551: 'ache',
#  552: 'transcendant',
#  553: 'disgraceful',
#  554: 'Gyros',
#  555: 'mortified',
#  556: 'fell',
#  557: 'onion',
#  558: 'relaxed',
#  559: 'name',
#  560: 'thought',
#  561: 'oh',
#  562: 'non-fancy',
#  563: 'ripped',
#  564: 'awkward',
#  565: 'brick',
#  566: 'Main',
#  567: 'this',
#  568: 'reservation',
#  569: 'Hiro',
#  570: 'Greek',
#  571: 'TIME',
#  572: 'changing',
#  573: 'groups',
#  574: '2',
#  575: 'untoasted',
#  576: 'Mary',
#  577: 'relationship',
#  578: 'nutshell',
#  579: 'outdoor',
#  580: 'why',
#  581: 'mom',
#  582: 'nicest',
#  583: 'Pricing',
#  584: 'glad',
#  585: 'Taco',
#  586: 'working/eating',
#  587: 'After',
#  588: 'lots',
#  589: 'poisoning',
#  590: 'Thoroughly',
#  591: 'negligent',
#  592: 'Long',
#  593: 'wife',
#  594: 'smelled',
#  595: 'Mom',
#  596: 'tried',
#  597: 'ice',
#  598: 'FS',
#  599: 'ago',
#  600: 'writing',
#  601: 'sides',
#  602: 'made',
#  603: 'money',
#  604: 'veal',
#  605: 'covered',
#  606: 'deep',
#  607: 'begin',
#  608: 'Gave',
#  609: ')',
#  610: 'stinks',
#  611: 'cool',
#  612: 'sad',
#  613: 'Maria',
#  614: 'lunch',
#  615: 'Baseball',
#  616: 'worst/annoying',
#  617: 'pumpkin',
#  618: 'under',
#  619: 'saving',
#  620: 'Dylan',
#  621: 'Delicious',
#  622: 'wo',
#  623: 'entire',
#  624: 'register',
#  625: 'hot',
#  626: 'pucks',
#  627: 'will',
#  628: 'haunt',
#  629: 'cheese',
#  630: 'bigger',
#  631: 'venture',
#  632: 'accordingly',
#  633: 'subpar',
#  634: 'burgers',
#  635: 'blue',
#  636: 'suffers',
#  637: 'UNREAL',
#  638: 'allergy',
#  639: 'shawarrrrrrma',
#  640: 'brownish',
#  641: 'customer',
#  642: 'goat',
#  643: 'fat',
#  644: 'Christmas',
#  645: 'recall',
#  646: 'suggestions',
#  647: 'hooked',
#  648: 'absolute',
#  649: 'Waited',
#  650: 'dressing',
#  651: 'tongue',
#  652: 'disappoint',
#  653: 'bites',
#  654: 'Always',
#  655: 'milkshake',
#  656: 'myself',
#  657: 'low',
#  658: 'giant',
#  659: 'Soggy',
#  660: 'article',
#  661: 'extensive',
#  662: 'Veggitarian',
#  663: 'barely',
#  664: 'proclaimed',
#  665: 'gotten',
#  666: 'I',
#  667: 'poorly',
#  668: 'hilarious',
#  669: 'REAL',
#  670: 'etc',
#  671: 'dealing',
#  672: 'terrific',
#  673: 'But',
#  674: 'back',
#  675: 'turkey',
#  676: 'fry',
#  677: 'correction',
#  678: 'dry',
#  679: 'gone',
#  680: 'including',
#  681: 'Yelpers',
#  682: 'owner/chef',
#  683: 'pan',
#  684: 'to',
#  685: 'desserts',
#  686: 'bamboo',
#  687: 'bathrooms',
#  688: 'Carly',
#  689: 'flavor',
#  690: 'The',
#  691: 'ingredients',
#  692: 'DELICIOUS',
#  693: 'manager',
#  694: 'us',
#  695: 'appalling',
#  696: 'well',
#  697: '30s',
#  698: 'anticipated',
#  699: 'Thus',
#  700: 'people',
#  701: 'hoping',
#  702: 'she',
#  703: 'putting',
#  704: '4',
#  705: 'figured',
#  706: 'biscuits',
#  707: 'wrap',
#  708: 'live',
#  709: 'homemade',
#  710: 'trying',
#  711: 'cold',
#  712: '&',
#  713: 'bowl',
#  714: 'gratuity',
#  715: 'shirt',
#  716: 'book',
#  717: 'Crostini',
#  718: 'college',
#  719: 'lot',
#  720: 'flavors',
#  721: 'considering',
#  722: 'grocery',
#  723: 'drink',
#  724: 'dog',
#  725: 'happened',
#  726: 'times',
#  727: 'moz',
#  728: 'stay',
#  729: 'smeared',
#  730: 'low-key',
#  731: 'treat',
#  732: 'Give',
#  733: 'apart',
#  734: 'dusted',
#  735: 'falafels',
#  736: 'living',
#  737: 'forever',
#  738: 'overwhelmed',
#  739: 'but',
#  740: 'steaks',
#  741: 'totally',
#  742: 'fluffy',
#  743: 'Breeze',
#  744: 'baby',
#  745: 'sit-down',
#  746: 'huge',
#  747: 'all',
#  748: 'officially',
#  749: 'chip',
#  750: 'Back',
#  751: 'mushrooms',
#  752: 'smaller',
#  753: 'tomato',
#  754: 'order',
#  755: 'wish',
#  756: 'assure',
#  757: 'reviews',
#  758: 'ways',
#  759: 'afternoon',
#  760: 'dedicated',
#  761: 'attached',
#  762: 'pita',
#  763: 'worries',
#  764: '!',
#  765: 'of',
#  766: 'cannoli',
#  767: 'older',
#  768: 'Cartel',
#  769: 'or',
#  770: 'looks',
#  771: 'portions',
#  772: 'Cute',
#  773: 'hummus',
#  774: 'Everything',
#  775: 'bathroom',
#  776: '40',
#  777: 'be',
#  778: 'similar',
#  779: 'added',
#  780: 'Kind',
#  781: 'Try',
#  782: 'sushi',
#  783: 'boba',
#  784: 'Any',
#  785: 'same',
#  786: 'Luke',
#  787: 'selection',
#  788: 'heads',
#  789: 'literally',
#  790: 'got',
#  791: 'dinner',
#  792: 'taco',
#  793: 'Rock',
#  794: 'noodles',
#  795: 'lukewarm',
#  796: 'speedy',
#  797: 'i',
#  798: 'bite',
#  799: 'fairly',
#  800: 'disagree',
#  801: '7.85',
#  802: 'LOVED',
#  803: 'weekly',
#  804: 'spice',
#  805: 'coming',
#  806: 'Italian',
#  807: 'meat',
#  808: 'leaves',
#  809: 'close',
#  810: 'pulled',
#  811: 'touched',
#  812: 'above',
#  813: 'brings',
#  814: 'butter',
#  815: 'drastically',
#  816: 'excellent',
#  817: 'puree',
#  818: 'Ironman',
#  819: 'flair',
#  820: 'hamburger',
#  821: 'in-house',
#  822: 'fuzzy',
#  823: 'dirt',
#  824: 'closed',
#  825: 'play',
#  826: 'friends',
#  827: 'cover',
#  828: 'pissd',
#  829: 'expensive',
#  830: 'Spend',
#  831: 'NASTY',
#  832: 'Weird',
#  833: 'non-customer',
#  834: 'great',
#  835: 'crowds',
#  836: 'ravoli',
#  837: 'overhaul',
#  838: 'operation',
#  839: 'dough',
#  840: 'means',
#  841: 'Nothing',
#  842: 'M',
#  843: 'gave',
#  844: 'Also',
#  845: 'guests',
#  846: 'reduction',
#  847: 'boiled',
#  848: 'curry',
#  849: 'summarize',
#  850: 'violinists',
#  851: 'Boy',
#  852: 'Pho',
#  853: 'wrapped',
#  854: 'atmosphere',
#  855: 'rapidly',
#  856: 'If',
#  857: 'towards',
#  858: 'Seat',
#  859: 'Del',
#  860: 'Paying',
#  861: 'cause',
#  862: 'sauces',
#  863: 'him',
#  864: 'Japanese',
#  865: 'biscuit',
#  866: 'indoor',
#  867: 'downright',
#  868: 'whatsoever',
#  869: 'supposed',
#  870: 'Sunday',
#  871: 'mean',
#  872: 'tasteless',
#  873: 'silently',
#  874: 'deal',
#  875: 'garlic',
#  876: 'Burger',
#  877: 'employee',
#  878: 'vain',
#  879: 'reasonable',
#  880: 'Caballero',
#  881: 'them',
#  882: 'highlighted',
#  883: 'Service',
#  884: 'pho',
#  885: 'come',
#  886: 'Attack',
#  887: 'block',
#  888: 'succulent',
#  889: 'crawfish',
#  890: 'space',
#  891: 'forth',
#  892: 'pub',
#  893: 'brunch',
#  894: 'must',
#  895: 'market',
#  896: 'yay',
#  897: 'Thai',
#  898: 'Oh',
#  899: 'Nargile',
#  900: 'stepped',
#  901: 'human',
#  902: 'where',
#  903: 'legs',
#  904: 'baklava',
#  905: 'pine',
#  906: 'boring',
#  907: 'Favorite',
#  908: 'make',
#  909: 'short',
#  910: 'prepared',
#  911: 'fiancé',
#  912: 'Grill',
#  913: 'tough',
#  914: 'next',
#  915: 'so',
#  916: 'prefer',
#  917: 'small',
#  918: 'potato',
#  919: 'attention',
#  920: 'ended',
#  921: 'town',
#  922: 'yukon',
#  923: 'its',
#  924: 'seasoning',
#  925: 'maintaining',
#  926: 'deserves',
#  927: 'To',
#  928: 'smoke',
#  929: 'drunk',
#  930: 'No',
#  931: 'ate',
#  932: 'nigiri',
#  933: 'fine',
#  934: 'zero',
#  935: 'although',
#  936: 'Steak',
#  937: 'finger',
#  938: 'ball',
#  939: 'salty',
#  940: 'tender',
#  941: 'GREAT',
#  942: 'attack',
#  943: 'sorely',
#  944: 'ca',
#  945: 'boxes',
#  946: 'kitchen',
#  947: 'crazy',
#  948: 'year',
#  949: 'Mushroom',
#  950: 'Jamaican',
#  951: 'bill',
#  952: 'TOLD',
#  953: 'preparing',
#  954: 'joy',
#  955: 'Hopefully',
#  956: 'shops',
#  957: 'Same',
#  958: 'Coming',
#  959: 'wildly',
#  960: 'personally',
#  961: 'job',
#  962: 'correct',
#  963: 'pricey',
#  964: 'further',
#  965: 'class',
#  966: 'mouth',
#  967: 'Sushi',
#  968: 'So',
#  969: 'kind',
#  970: 'toasted',
#  971: 'loyal',
#  972: 'sliced',
#  973: '$',
#  974: 'known',
#  975: '%',
#  976: 'wall',
#  977: 'meet',
#  978: '?',
#  979: 'dude',
#  980: 'ever',
#  981: 'chefs',
#  982: 'perpared',
#  983: 'trap',
#  984: 'want',
#  985: 'inflate',
#  986: 'That',
#  987: 'daughter',
#  988: 'exactly',
#  989: 'duck',
#  990: 'long',
#  991: 'Soups',
#  992: 'eel',
#  993: 'slaw',
#  994: 'avoided',
#  995: 'Much',
#  996: 'Talk',
#  997: 'ventilation',
#  998: 'Bussell',
#  999: 'packed',
#  ...}

# %% [markdown]
# ## 轉換句子為bag of words型式

# %%
def _get_bag_of_words_vector(sentence, word_index_dic, whole_words):
    sentence = sentence
    #創建一個vector
    # np.zeros()可以定义数据全为0的向量或矩阵
    vector=np.zeros(len(whole_words))
    for word in nltk.word_tokenize(sentence):
        if word in whole_words:
            #所有的單詞需要有對應的 index,評價內有出現的單詞取出，找到對應的 index，將向量中這個位置的值 +1。
            vector[word_index_dic[word]]+=1
    return vector

# %%
_get_bag_of_words_vector('Wow... Loved this place.', word_index, whole_words)
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])
